# %%
# import all dependencies first
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Dense, LSTM
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Generating the datasets

# %% [markdown]
# ## Problem 1 dataset

# %%
# Generate nparray of bits (length= 50), sequence size= 100000
MAX_BITS = 50
NUM_SEQUENCES = 100000
seq_1 = np.random.randint(2,size=(NUM_SEQUENCES, MAX_BITS)).astype('float32')
non_zeros = np.count_nonzero(seq_1,axis=1)
labels_1 = [0 if c % 2 == 0 else 1 for c in non_zeros]
labels_1 = np.asarray(labels_1,dtype='float32')
in_file=np.savetxt('input1.txt', seq_1, fmt="%i")
out_file=np.savetxt('result1.txt', labels_1, fmt="%i")

# %% [markdown]
# ## Problem 2 dataset

# %%
# Generate nparray of bits with varying length (max length= 50), sequence size = 100000
seq_2 = []
labels_2 = []
for i in range(NUM_SEQUENCES):
    bit_size = np.random.randint(1, MAX_BITS + 1)
    val = np.random.randint(2,size=bit_size).astype('float32')
    seq_2.append(val)
    labels_2.append(0 if sum(val) % 2 == 0 else 1)
seq_2 = np.asarray(seq_2)
labels_2 = np.asarray(labels_2,dtype='float32')
with open('input2.txt','w') as in_file1:
    for row in seq_2:
        np.savetxt(in_file1,[row],fmt="%i")
out_file1=np.savetxt('result2.txt',labels_2,fmt="%i")

# %% [markdown]
# # Training & Testing LSTM Model

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ### Load dataset 1 and split 80/20 for train/test

# %%
# load them from the in/out file(s)
seq_1 =np.loadtxt('input1.txt', dtype='float' )
seq_1 =np.array(seq_1)
labels_1 =np.loadtxt('result1.txt', dtype='int32' )
labels_1=np.array(labels_1)
seq_1 = np.expand_dims(seq_1 ,-1)
labels_1 = np.expand_dims(labels_1,-1)
split_ratio = int(len(seq_1) * 0.8)
train_set_in_1 = seq_1[:split_ratio]
test_set_in_1 = seq_1[split_ratio+1:]
train_set_out_1 = labels_1[:split_ratio]
test_set_out_1 = labels_1[split_ratio+1:]

# %% [markdown]
# ### Define model

# %%
model_1 = Sequential()
model_1.add(LSTM(units=32,input_shape=(50,1)))
model_1.add(Dropout(0.2))
model_1.add(Dense(1,activation='sigmoid'))
model_1.summary()
#sgd = SGD(lr=0.001, momentum=0.9)
adam = Adam(lr=0.001)
model_1.compile(optimizer=adam,loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
model_1.fit(train_set_in_1,train_set_out_1,epochs=20,batch_size=128,validation_split=0.2,shuffle=False)
# Out:
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/20
# 64000/64000 [==============================] - 13s 201us/sample - loss: 0.6934 - accuracy: 0.5004 - val_loss: 0.6931 - val_accuracy: 0.4969
# Epoch 2/20
# 64000/64000 [==============================] - 11s 168us/sample - loss: 0.6933 - accuracy: 0.4993 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 3/20
# 64000/64000 [==============================] - 11s 172us/sample - loss: 0.6932 - accuracy: 0.5032 - val_loss: 0.6932 - val_accuracy: 0.4976
# Epoch 4/20
# 64000/64000 [==============================] - 11s 169us/sample - loss: 0.6933 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.5011
# Epoch 5/20
# 64000/64000 [==============================] - 11s 171us/sample - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6932 - val_accuracy: 0.4991
# Epoch 6/20
# 64000/64000 [==============================] - 11s 169us/sample - loss: 0.6932 - accuracy: 0.5033 - val_loss: 0.6932 - val_accuracy: 0.4963
# Epoch 7/20
# 64000/64000 [==============================] - 10s 163us/sample - loss: 0.6932 - accuracy: 0.5032 - val_loss: 0.6932 - val_accuracy: 0.4992
# Epoch 8/20
# 64000/64000 [==============================] - 10s 162us/sample - loss: 0.6932 - accuracy: 0.5021 - val_loss: 0.6932 - val_accuracy: 0.4983
# Epoch 9/20
# 64000/64000 [==============================] - 10s 162us/sample - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6932 - val_accuracy: 0.4961
# Epoch 10/20
# 64000/64000 [==============================] - 11s 167us/sample - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.5021
# Epoch 11/20
# 64000/64000 [==============================] - 11s 167us/sample - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.4981
# Epoch 12/20
# 64000/64000 [==============================] - 10s 162us/sample - loss: 0.6932 - accuracy: 0.5026 - val_loss: 0.6932 - val_accuracy: 0.4989
# Epoch 13/20
# 64000/64000 [==============================] - 11s 173us/sample - loss: 0.6932 - accuracy: 0.5006 - val_loss: 0.6932 - val_accuracy: 0.4973
# Epoch 14/20
# 64000/64000 [==============================] - 11s 169us/sample - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.4981
# Epoch 15/20
# 64000/64000 [==============================] - 11s 165us/sample - loss: 0.6932 - accuracy: 0.5030 - val_loss: 0.6932 - val_accuracy: 0.5008
# Epoch 16/20
# 64000/64000 [==============================] - 11s 164us/sample - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4994
# Epoch 17/20
# 64000/64000 [==============================] - 11s 166us/sample - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6932 - val_accuracy: 0.4983
# Epoch 18/20
# 64000/64000 [==============================] - 10s 163us/sample - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6932 - val_accuracy: 0.4992
# Epoch 19/20
# 64000/64000 [==============================] - 11s 166us/sample - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.4992
# Epoch 20/20
# 64000/64000 [==============================] - 10s 162us/sample - loss: 0.6931 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.4996

# %% [markdown]
# ### Testing

# %%
eval_model_1 = model_1.evaluate(x=test_set_in_1,y=test_set_out_1)
# Out:
# 19999/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## Problem 2 (with pre-padding)

# %% [markdown]
# ### Load dataset 2, pre-pad, and split 80/20 for train/test

# %%
seq_2 = []
labels_2 = []
# load them from the in/out file(s)
for line in  open ('input2.txt','r') :
    temp=np.array(list(i for i in line.split(' ')))
    seq_2.append(temp)
seq_2 =np.array(seq_2)
seq_2  = pad_sequences(seq_2 , dtype='float32',maxlen=MAX_BITS,padding='pre')
labels_2 =np.loadtxt('result2.txt', dtype='int32' )
labels_2=np.array(labels_2)
seq_2= np.expand_dims(seq_2,-1)
labels_2 = np.expand_dims(labels_2,-1)
split_ratio = int(len(seq_2) * 0.8)
train_set_in_2 = seq_2[:split_ratio]
test_set_in_2 = seq_2[split_ratio+1:]
train_set_out_2 = labels_2[:split_ratio]
test_set_out_2 = labels_2[split_ratio+1:]

# %% [markdown]
# ### Define Model

# %%
model_2 = Sequential()
model_2.add(LSTM(units=32,input_shape=(50,1)))
model_2.add(Dropout(0.2))
model_2.add(Dense(1,activation='sigmoid'))
model_2.summary()
#sgd = SGD(lr=0.001, momentum=0.9)
adam = Adam(lr=0.001)
model_2.compile(optimizer=adam,loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
model_2.fit(train_set_in_2,train_set_out_2,epochs=20,batch_size=128,validation_split=0.2,shuffle=False)
# Out:
# Train on 64000 samples, validate on 16000 samples
# Epoch 1/20
# 64000/64000 [==============================] - 12s 193us/sample - loss: 0.6933 - accuracy: 0.5064 - val_loss: 0.6932 - val_accuracy: 0.5082
# Epoch 2/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.6930 - accuracy: 0.5138 - val_loss: 0.6930 - val_accuracy: 0.5153
# Epoch 3/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.6928 - accuracy: 0.5122 - val_loss: 0.6927 - val_accuracy: 0.5059
# Epoch 4/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.6924 - accuracy: 0.5135 - val_loss: 0.6917 - val_accuracy: 0.5122
# Epoch 5/20
# 64000/64000 [==============================] - 10s 161us/sample - loss: 0.6896 - accuracy: 0.5124 - val_loss: 0.6823 - val_accuracy: 0.5182
# Epoch 6/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.6737 - accuracy: 0.5240 - val_loss: 0.6655 - val_accuracy: 0.5351
# Epoch 7/20
# 64000/64000 [==============================] - 10s 159us/sample - loss: 0.5545 - accuracy: 0.6395 - val_loss: 0.1443 - val_accuracy: 0.9427
# Epoch 8/20
# 64000/64000 [==============================] - 10s 160us/sample - loss: 0.4374 - accuracy: 0.8708 - val_loss: 1.6484 - val_accuracy: 0.4523
# Epoch 9/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.9867 - accuracy: 0.4503 - val_loss: 0.7280 - val_accuracy: 0.4774
# Epoch 10/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.6675 - accuracy: 0.5361 - val_loss: 0.6491 - val_accuracy: 0.5583
# Epoch 11/20
# 64000/64000 [==============================] - 10s 157us/sample - loss: 0.6494 - accuracy: 0.5550 - val_loss: 0.6417 - val_accuracy: 0.5714
# Epoch 12/20
# 64000/64000 [==============================] - 10s 157us/sample - loss: 0.6378 - accuracy: 0.5711 - val_loss: 0.6202 - val_accuracy: 0.6028
# Epoch 13/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.5118 - accuracy: 0.7118 - val_loss: 0.1919 - val_accuracy: 0.9583
# Epoch 14/20
# 64000/64000 [==============================] - 10s 157us/sample - loss: 0.1329 - accuracy: 0.9622 - val_loss: 0.0874 - val_accuracy: 0.9632
# Epoch 15/20
# 64000/64000 [==============================] - 10s 158us/sample - loss: 0.0678 - accuracy: 0.9805 - val_loss: 0.0346 - val_accuracy: 0.9958
# Epoch 16/20
# 64000/64000 [==============================] - 10s 159us/sample - loss: 0.0415 - accuracy: 0.9956 - val_loss: 0.0302 - val_accuracy: 0.9959
# Epoch 17/20
# 64000/64000 [==============================] - 10s 163us/sample - loss: 0.0577 - accuracy: 0.9741 - val_loss: 0.0612 - val_accuracy: 0.9618
# Epoch 18/20
# 64000/64000 [==============================] - 10s 160us/sample - loss: 0.0673 - accuracy: 0.9603 - val_loss: 0.0591 - val_accuracy: 0.9622
# Epoch 19/20
# 64000/64000 [==============================] - 10s 162us/sample - loss: 0.0654 - accuracy: 0.9589 - val_loss: 0.0581 - val_accuracy: 0.9621
# Epoch 20/20
# 64000/64000 [==============================] - 10s 164us/sample - loss: 0.0618 - accuracy: 0.9615 - val_loss: 0.0560 - val_accuracy: 0.9627

# %% [markdown]
# ### Testing

# %%
eval_model_2 = model_2.evaluate(x=test_set_in_2,y=test_set_out_2)
# Out:
# 19999/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
